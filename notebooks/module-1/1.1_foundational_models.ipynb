# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or capital. It’s a natural satellite of Earth, with no official cities or political divisions. If you’re thinking of a fictional universe, some stories invent a lunar capital, but that’s purely fictional. Want me to name some fictional examples or talk about future lunar settlements?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1039, 'prompt_tokens': 13, 'total_tokens': 1052, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cy45ABH3c9KVIVEEwtluEd8DdytsJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bbeb9-d4f0-7f21-b3c7-dfde82e2b8cb-0', usage_metadata={'input_tokens': 13, 'output_tokens': 1039, 'total_tokens': 1052, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. It’s a natural satellite of Earth, with no official cities or political divisions. If you’re thinking of a fictional universe, some stories invent a lunar capital, but that’s purely fictional. Want me to name some fictional examples or talk about future lunar settlements?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-Cy4cN0Rr8y6moZrP8Muds0xDMNLsh',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 391,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 320,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 404}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re thinking in a fictional sense, you could invent a name like “Lunapolis” or “Selene City.” Want ideas for a sci‑fi setting or real-world space governance?

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite with no permanent human settlements or government.
#
# If you're asking about potential future lunar bases, there are currently only occasional visits to the Moon by astronauts, but no established cities or capitals.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='f312fbf3-b783-42c8-b995-b405af664119'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or permanent population, so it has no capital. If a future lunar polity were established, its capital would be whatever city the governing body designates.\n\nIf you’re thinking of fiction, I can suggest a name for a lunar capital (e.g., Lunopolis or Selene City) for your story.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 981, 'prompt_tokens': 13, 'total_tokens': 994, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cy7UdAOAMizXeEOrddpOCcR6NTX3r', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bbf81-e324-78c1-8e75-9636bcc57630-0', usage_metadata={'input_tokens': 13, 'output_tokens': 981, 'total_tokens': 994, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or permanent population, so it has no capital. If a future lunar polity were established, its capital would be whatever city the governing body designates.
#
# If you’re thinking of fiction, I can suggest a name for a lunar capital (e.g., Lunopolis or Selene City) for your story.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='6628ef05-ce30-4af3-aee4-10e434fde9ad'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='0c48662d-a624-4ae5-ba14-1a6af688e2b7'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='cc6c9e29-3423-4f0b-9074-58b33051fc24'),
#               AIMessage(content='In reality there’s no capital of the Moon and no Moon-wide government. Luna City is a fictional concept you can use for stories, games, or worldbuilding. Here’s a fleshed-out idea you can run with or adapt.\n\nConcept snapshot\n- Luna City is the ceremonial and administrative capital of the Lunar Commonwealth, a federation of lunar settlements and stations. It sits on a sunlit rim near the Moon’s southern pole, with access to water ice in nearby shadowed craters and long, stable daylight on the rim.\n\nGeography and urban form\n- Location: A crescent-shaped urban belt around the rim of a large southern-polar crater, where parts are bathed in near-constant sunlight while shadowed floors host ice and minerals.\n- Layout: Concentric rings linked by lunar elevators, maglev tram lines, and tunnel corridors. The innermost ring houses the Capitol Complex and central plaza; middle rings are residential and social districts; outer rings are research parks, industrial hubs, and production facilities.\n- Subsurface and shielding: Much of the city is pressurized and shielded in lava tubes and man-made caverns, reducing radiation exposure and stabilizing temperatures.\n- Architecture: 3D-printed regolith blocks, carbon-fiber shells, and inflatable habitats covered with regolith shielding. Transparent or lit skylights provide artificial daylight cycles in some districts.\n\nGovernance and society\n- Government: The Lunar Commonwealth is a representative union of settlements. Luna City hosts the Commonwealth Council, the Justice Dome, and key ministries (Science, Resources, Culture).\n- Citizenship and life: Residents include long-term settlers, researchers, engineers, and visiting diplomats. Many work in rotating shifts to keep the city running in a largely 1/6 g environment.\n- Law and order: A mix of civil law and planetary governance; conflict resolution emphasizes consensus-building, with a fast-response emergency corps for natural or technical crises.\n\nEconomy and technology\n- Core industries: Water ice extraction and processing, space-resource research, solar power generation, life-support systems, 3D-printed construction, and advanced robotics.\n- In-situ resource use: Hydrogen/electric propulsion components, oxygen, and building materials produced on-site to reduce Earth dependence.\n- Daily tech: Advanced telepresence, modular habitats, autonomous cargo drones, gravity-sim methods in certain zones to mitigate bone/muscle loss.\n\nDaily life and culture\n- Living: Families and researchers live in modular apartments with shared hydroponic gardens, communal kitchens, and gravity-regulated recreation spaces.\n- Work life: Engineers and scientists run long-term experiments in lunar labs, while transit operators and maintenance crews keep the city functioning around the clock.\n- Culture: A fusion of Earth cultures adapted to lunar life—art, music, and storytelling that reflect the stark beauty of the Moon, dust management rituals, and seasonal festivals tied to the orbital day-night cycle.\n- Education and research: A major center for lunar science, astrobiology analogs, materials science from regolith, and life-support innovation.\n\nInfrastructure and transport\n- Power: A backbone of solar farms on sunlit rims, with nuclear backups and high-density energy storage for the long lunar nights.\n- Transport: Gravity-stabilized trams, electric rovers, airlocks for surface excursions, and vertical transport via lunar elevators between rings and surface hubs.\n- Water and life support: Closed-loop systems for air, water, and food; ice mined from permanently shadowed craters is processed into water and oxygen.\n\nLandmarks and notable places\n- The Capitol Glass: A transparent-domed plaza where weekly assemblies are broadcast to all settlements.\n- Icewell Plaza: A public space built atop a mined water-ice deposit, with a sculpture that glows as ice sublimates under lamp and solar glow.\n- The Archive Spire ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is not a real place on the Moon today, but a rich fictional concept you can use for stories, games, or worldbuilding. Below is a thorough, self-contained profile you can adopt or adapt. If you want a different tone (hard sci-fi, utopian, dystopian, corporate-ruled, etc.), tell me and I’ll tailor it.
#
# Overview
# - Name and role: Luna City, officially the Capital of the Moon. It’s the political heart, primary research hub, and cultural beacon of lunar civilization.
# - Population: Roughly 2–4 million residents, with a constant influx of visiting scientists, traders, and diplomats. A sizable portion are lunar-born (those who have spent most or all of their lives in lunar habitats) alongside Earth-born settlers and descendants of earlier colonies.
# - Mood and vibe: A sleek blend of resilient frontier practicality and high-tech refinement. The city feels at once ancient (in its lava-tube histories and basalt architecture) and future-shiny (grav lift systems, AI-enabled governance, advanced life support).
#
# Location and geography
# - Setting: On the near side of the Moon, in a shallow basin around the equator where sunlight is abundant for most of the lunar day. The city straddles a rim of basalt cliffs and a network of lava tubes that extend beneath the surface.
# - Strategic advantages: Close proximity to Earth for political legitimacy and trade, abundant solar energy on the sunlit side, and natural lava tubes that host subterranean districts with stable temperatures and reduced dust exposure.
# - Environment: The surface is ringed by solar farms and shielded by regolith barriers. Interior habitats rely on closed-loop ecology (water recycling, hydroponics, atmospheric processing). There’s almost no natural atmosphere, so life-support is omnipresent in every district.
#
# History and governance
# - Founding arc: Began as a collection of mining and research outposts in the late 22nd century. It evolved from a corporate hub into a self-governing city-state after a peaceful push for lunar autonomy, culminating in the Lunar Charter of 2260, which established Luna City as the political capital and a beacon for lunar rights and science.
# - Political structure: A bicameral Lunar Assembly (an elected body representing districts and interest groups) and a rotating Executive Directorate (an 8–12 person council elected by the Assembly for 4–6 year terms). A Lunar Supreme Court settles constitutional disputes; a Librarium-Archive Council preserves historical records and research integrity.
# - Citizenship and law: People born on the Moon have de facto lunar citizenship; Earth-born residents gain lunar status after a probationary period. Rights cover suffrage, property, education, healthcare, and participation in public projects. The city prides itself on transparent governance and open data, with most records accessible in a public archive.
#
# City layout and districts
# - Central district: Government Quarter centered on the Grand Dome, housing the Assembly chambers, the Executive Directorate building, and the Supreme Court. The Dome is a dramatic, 1–2 km-wide glass-and-steel hemisphere that hosts ceremonies and serves as a symbol of lunar unity.
# - Cultural Quarter: Museums, universities, theatres, lunar music festivals, and public art. A prominent feature is the Lumen Arc, a curved spectrum of lighting that traces ideas and stories across the night sky.
# - Residential Crescent: Packed, modular housing in stacked cells or ringed neighborhoods. Housing is configurable to suit families, researchers, or remote workers. Parks, community kitchens, and small clinics are interspersed to preserve a sense of neighborhood.
# - Industrial Belt: Workshops, 3D-printing foundries, microfabrication labs, and energy plants. Helium-3 fusion microreactors and solar arrays power the city. The belt also contains the city’s utility infrastructure—air processing, water recovery, waste recycling.
# - Research and Education District: The Selene University Campus, planetary science labs, life-support R&D, and citizen-science centers. It’s a magnet for visiting scholars and student exchanges.
# - Orbital and Transportation Hub: A spaceport and transit center with lunar elevators, vacuum-tube maglevs, and autonomous shuttles. It links Luna City with cargo rings in orbit, Earth, and nearby colonies.
# - Subterranean Rings: In the lava tubes beneath the surface, there are cooler, more controlled habitats: storage for water-ice, cryogenic labs, and additional living space. Tube cities use rotating sections to simulate Earth-like gravity in long corridors.
#
# Architecture and technology
# - Aesthetics: A marriage of brutalist basalt forms and transparent/silicate panels. White, reflective surfaces contrast with dark basalt, punctuated by green-projected bio-lights and holographic signage.
# - Structures: Mixed-use towers with modular apartments, public plazas, and agricultural terraces. The Grand Dome is a touristic and political symbol; nearby are the Hall of Echoes (a history museum) and the Moonlight Atrium (public gathering space).
# - Energy and environment: Solar farms cover crater rims and plateaus. Helium-3 fusion microreactors provide steady baseload power. Water is harvested from ice near the poles and recycled through closed-loop systems. Oxygen is generated onboard habitats and scrubbed in life-support facilities.
# - Gravity management: The Moon’s natural gravity (about 0.16 g) is comfortable for short-term activities but requires deliberate design for long-term health. Habitats use a combination of slightly rotating sections and gravity-manipulation corridors to approximate 1 g in living areas, while lifts and corridors minimize pseudo-forces for workers and athletes.
# - Transportation infrastructure: Vacuum-tube maglev links, autonomous rovers, and pedestrian-friendly districts connected by skybridges. Personal gravity-limited pods and bike-like exo-frames enable mobility for residents in larger dome complexes.
#
# Economy and daily life
# - Key industries: Helium-3 mining (exported back to Earth and used for research), advanced manufacturing from lunar regolith (ceramics, metals, and composites), biotech and life-support systems, and astronomical instrumentation. Tourism to the Grand Dome and scenic crater walks is also a growing sector.
# - Daily life: Residents live in modular apartments with reconfigurable spaces. Hydroponic farms provide fresh produce year-round. Education focuses on science, engineering, and arts to reflect lunar identity. Community programs emphasize health, fitness, and cultural exchange with Earth.
# - Culture and language: Earth languages persist, but a lunar creole (Luna Patois) and secondary dialects are common in markets and neighborhoods. Public art and festivals celebrate lunar cycles, Earth heritage, and scientific achievements.
# - Food and sustenance: Food is largely grown locally—leafy greens, tomatoes, herbs, and fungi—augmented by imported goods. In-dome cafes offer hyper-local dishes using 3D-printed proteins and algae-based products.
#
# Society and culture
# - Social fabric: A merit-based but inclusive culture values scientific curiosity, craftsmanship, and community welfare. Education is universal, and medical care is high-quality and accessible.
# - Arts and festivals: The Night of the Two Moons festival (a cultural reflection on lunar cycles), Moon Opera, and the Harvest of Helium-3 (a festival celebrating energy and technological breakthroughs) are annual highlights.
# - Education and research: The Selene University and its affiliated institutes train engineers, physicians, planetary scientists, and artists. Public lectures and citizen-science programs are common in the Cultural Quarter.
#
# Security and resilience
# - Public safety: A Lunar Security Service coordinates civil security, disaster response, and airspace traffic control for near-Earth approaches. They emphasize de-escalation, crowd management, and space-aware policing.
# - Hazards and resilience: A constant risk profile includes radiation exposure (mitigated by shielding and habitat design), micrometeorite impacts (shields and reinforced domes), and dust storms (minimized by exterior enclosures and filtration). Redundant life-support and energy systems ensure city-wide resilience.
# - Emergency protocols: Drills for habitat breach, solar storm events, and water-ice shortages are routine. Subsurface facilities provide a safe haven during extreme events.
#
# Notable landmarks and institutions
# - The Grand Dome: The political and ceremonial heart; a massive glass dome that doubles as a civic amphitheater.
# - The Lumen Arc: A public light sculpture along the Cultural Quarter, symbolizing lunar knowledge and memory.
# - Selene University: Premier center for lunar science, engineering, and arts education.
# - The Archive of Tides: A grand library and record-keeping hall preserving lunar history, science, and cultural artifacts.
# - The Halo Observatory: A high-altitude telescope complex that doubles as a research hub and tourist destination.
# - The Lunar Green: A large, multi-species hydroponic farm and botanical center that also serves as a public park.
#
# Plausible challenges and tensions
# - Resource balance: Balancing helium-3 exports with home energy needs and maintaining autonomy from Earth-based interests.
# - Population growth: Housing and resource demands strain less expandable lunar basins; modular expansion is essential.
# - Health concerns: Prolonged low gravity can affect bone density and muscle mass; fitness and rotating gravity corridors help mitigate.
# - Environmental ethics: The city enforces strict lunar environmental rules to avoid contamination of pristine sites and to protect ancient lava tubes.
#
# Genre variations and flavor
# - Hard sci-fi utopia: Emphasize clean energy, transparent governance, and thriving science culture; near-Earth diplomacy is central.
# - Corporate-dystopia: A powerful consortium dominates Luna City’s economy; political power is unevenly distributed; labor unions and underground networks shape events.
# - Space opera epic: Grand political intrigue, interstellar diplomacy, and a sense of ancient lunar mystique behind the city’s architecture.
# - Detective mystery: A crime or conspiracy centers around the Grand Dome, the Archive, or a research lab, with lunar culture and quirks shaping the investigation.
#
# A quick starter prompt
# - The Festival of Two Moons is about to begin, but a critical energy coil at the Halo Observatory fails. As the city braces for a power outage, a diverse team must race through lunar tunnels and arcades, uncovering a web of political intrigue, scientific rivalries, and a hidden history of Luna City itself.
#
# Would you like me to tailor this to a specific genre, time period, or character roster? I can also sketch a few districts in more detail (layout, major buildings, typical inhabitants, day-in-the-life scenes) or write a sample scene set in Luna City.
