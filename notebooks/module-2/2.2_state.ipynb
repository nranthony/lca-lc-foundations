# %%
from dotenv import load_dotenv

load_dotenv()

from rich.console import Console
console = Console(width=96)

# %%
from langchain.agents import AgentState

class CustomState(AgentState):
    favourite_colour: str

# %% [markdown]
# ## Write to state

# %%
from langchain.tools import tool, ToolRuntime
from langgraph.types import Command
from langchain.messages import ToolMessage

@tool
def update_favourite_colour(favourite_colour: str, runtime: ToolRuntime) -> Command:
    """Update the favourite colour of the user in the state once they've revealed it."""
    return Command(update={
        "favourite_colour": favourite_colour, 
        "messages": [ToolMessage("Successfully updated favourite colour", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=[update_favourite_colour],
    checkpointer=InMemorySaver(),
    state_schema=CustomState
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    { "messages": [HumanMessage(content="My favourite colour is green")]},
    {"configurable": {"thread_id": "1"}}
)

# %%
from pprint import pprint

console.print(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='My favourite colour is green',
#             additional_kwargs={},
#             response_metadata={},
#             id='bd8907cc-df83-428f-b976-98a01e29f257'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 283,
#                     'prompt_tokens': 141,
#                     'total_tokens': 424,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 256,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPRfRRuaAACZAEXg9GRSwFuwlas8',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--019bc39e-dbdf-7151-adbe-62d0c8e08cb2-0',
#             tool_calls=[
#                 {
#                     'name': 'update_favourite_colour',
#                     'args': {'favourite_colour': 'green'},
#                     'id': 'call_TRPLOnXmaJZ88WCaPmGA2qn3',
#                     'type': 'tool_call'
#                 }
#             ],
#             usage_metadata={
#                 'input_tokens': 141,
#                 'output_tokens': 283,
#                 'total_tokens': 424,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 256}
#             }
#         ),
#         ToolMessage(
#             content='Successfully updated favourite colour',
#             name='update_favourite_colour',
#             id='5ac80760-e2c3-4104-9d5f-4bb941f8cf48',
#             tool_call_id='call_TRPLOnXmaJZ88WCaPmGA2qn3'
#         ),
#         AIMessage(
#             content='Done—your favourite colour is now green. If you’d like, I can tailor future
# responses or recommendations around green, or I can update other preferences as well.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 234,
#                     'prompt_tokens': 179,
#                     'total_tokens': 413,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 192,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPRid6XrftWz3D9im3CVRGBW3D2z',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc39e-ea0c-7d33-bd29-a856740cd80d-0',
#             usage_metadata={
#                 'input_tokens': 179,
#                 'output_tokens': 234,
#                 'total_tokens': 413,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 192}
#             }
#         )
#     ],
#     'favourite_colour': 'green'
# }

# %%
response = agent.invoke(
    { 
        "messages": [HumanMessage(content="Hello, how are you?")],
        "favourite_colour": "green"
    },
    {"configurable": {"thread_id": "10"}}
)

console.print(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='Hello, how are you?',
#             additional_kwargs={},
#             response_metadata={},
#             id='7017590c-5e66-480a-ab2c-47df8f91bf29'
#         ),
#         AIMessage(
#             content='Hi there! I’m here and ready to help with whatever you need. I don’t have
# feelings, but I can answer questions, help with tasks, or chat. What would you like to do
# today?',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 307,
#                     'prompt_tokens': 142,
#                     'total_tokens': 449,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 256,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPTBGGz4tebyxa0z44gx9NvoPxWj',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc3a0-49ab-7351-bbb1-6bb737acd98d-0',
#             usage_metadata={
#                 'input_tokens': 142,
#                 'output_tokens': 307,
#                 'total_tokens': 449,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 256}
#             }
#         ),
#         HumanMessage(
#             content='Hello, how are you?',
#             additional_kwargs={},
#             response_metadata={},
#             id='d5e8af8c-8887-4c17-94f0-c610818fb6b0'
#         ),
#         AIMessage(
#             content='Hello! I’m here and ready to help with whatever you need. How can I assist
# you today? If you’re not sure, tell me what you’re curious about or what task you’d like to work
# on.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 245,
#                     'prompt_tokens': 200,
#                     'total_tokens': 445,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 192,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPTO28Dcskw9prUOIcMYbWWG828q',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc3a0-7d51-7f32-a892-de6f8cf90788-0',
#             usage_metadata={
#                 'input_tokens': 200,
#                 'output_tokens': 245,
#                 'total_tokens': 445,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 192}
#             }
#         )
#     ],
#     'favourite_colour': 'green'
# }

# %% [markdown]
# ## Read state

# %%
@tool
def read_favourite_colour(runtime: ToolRuntime) -> str:
    """Read the favourite colour of the user from the state."""
    try:
        return runtime.state["favourite_colour"]
    except KeyError:
        return "No favourite colour found in state"

agent = create_agent(
    "gpt-5-nano",
    tools=[update_favourite_colour, read_favourite_colour],
    checkpointer=InMemorySaver(),
    state_schema=CustomState
)

# %%
response = agent.invoke(
    { "messages": [HumanMessage(content="My favourite colour is green")]},
    {"configurable": {"thread_id": "1"}}
)

console.print(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='My favourite colour is green',
#             additional_kwargs={},
#             response_metadata={},
#             id='9cb235e5-52c1-472d-a4c3-9531859d2596'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 219,
#                     'prompt_tokens': 162,
#                     'total_tokens': 381,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 192,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPUn8wbqB4nCUdFa5Y92fNbEK1c0',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--019bc3a1-cdc1-7061-91c4-c61445bffe1f-0',
#             tool_calls=[
#                 {
#                     'name': 'update_favourite_colour',
#                     'args': {'favourite_colour': 'green'},
#                     'id': 'call_6G9dro5YUFCxdIKkImM6pOWU',
#                     'type': 'tool_call'
#                 }
#             ],
#             usage_metadata={
#                 'input_tokens': 162,
#                 'output_tokens': 219,
#                 'total_tokens': 381,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 192}
#             }
#         ),
#         ToolMessage(
#             content='Successfully updated favourite colour',
#             name='update_favourite_colour',
#             id='2417cd75-4774-478a-91d5-cf61a59e0c46',
#             tool_call_id='call_6G9dro5YUFCxdIKkImM6pOWU'
#         ),
#         AIMessage(
#             content="Done—I've saved green as your favourite colour.\n\nWould you like me to
# tailor color-themed suggestions or themes in our interactions based on this? Also, I can quickly
# confirm the current saved colour if you’d like.",
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 756,
#                     'prompt_tokens': 200,
#                     'total_tokens': 956,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 704,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPUpbYyeHldClxgrx7Yw0MsO8VFL',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc3a1-dcb0-7d51-ae11-487d68577f1f-0',
#             usage_metadata={
#                 'input_tokens': 200,
#                 'output_tokens': 756,
#                 'total_tokens': 956,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 704}
#             }
#         )
#     ],
#     'favourite_colour': 'green'
# }

# %%
response = agent.invoke(
    { "messages": [HumanMessage(content="What's my favourite colour?")]},
    {"configurable": {"thread_id": "1"}}
)

console.print(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='My favourite colour is green',
#             additional_kwargs={},
#             response_metadata={},
#             id='9cb235e5-52c1-472d-a4c3-9531859d2596'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 219,
#                     'prompt_tokens': 162,
#                     'total_tokens': 381,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 192,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPUn8wbqB4nCUdFa5Y92fNbEK1c0',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--019bc3a1-cdc1-7061-91c4-c61445bffe1f-0',
#             tool_calls=[
#                 {
#                     'name': 'update_favourite_colour',
#                     'args': {'favourite_colour': 'green'},
#                     'id': 'call_6G9dro5YUFCxdIKkImM6pOWU',
#                     'type': 'tool_call'
#                 }
#             ],
#             usage_metadata={
#                 'input_tokens': 162,
#                 'output_tokens': 219,
#                 'total_tokens': 381,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 192}
#             }
#         ),
#         ToolMessage(
#             content='Successfully updated favourite colour',
#             name='update_favourite_colour',
#             id='2417cd75-4774-478a-91d5-cf61a59e0c46',
#             tool_call_id='call_6G9dro5YUFCxdIKkImM6pOWU'
#         ),
#         AIMessage(
#             content="Done—I've saved green as your favourite colour.\n\nWould you like me to
# tailor color-themed suggestions or themes in our interactions based on this? Also, I can quickly
# confirm the current saved colour if you’d like.",
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 756,
#                     'prompt_tokens': 200,
#                     'total_tokens': 956,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 704,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPUpbYyeHldClxgrx7Yw0MsO8VFL',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc3a1-dcb0-7d51-ae11-487d68577f1f-0',
#             usage_metadata={
#                 'input_tokens': 200,
#                 'output_tokens': 756,
#                 'total_tokens': 956,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 704}
#             }
#         ),
#         HumanMessage(
#             content="What's my favourite colour?",
#             additional_kwargs={},
#             response_metadata={},
#             id='ac62aca2-04bf-41b0-958b-a3198330dfc6'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 149,
#                     'prompt_tokens': 258,
#                     'total_tokens': 407,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 128,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPVGIi190Ghy7QYqvQxrd1h7JcDK',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--019bc3a2-4649-7660-8c2d-09d4fba4aac8-0',
#             tool_calls=[
#                 {
#                     'name': 'read_favourite_colour',
#                     'args': {},
#                     'id': 'call_ZhQXuFuztghOzswFbdHnus03',
#                     'type': 'tool_call'
#                 }
#             ],
#             usage_metadata={
#                 'input_tokens': 258,
#                 'output_tokens': 149,
#                 'total_tokens': 407,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 128}
#             }
#         ),
#         ToolMessage(
#             content='green',
#             name='read_favourite_colour',
#             id='526bb3fd-f794-4b10-8e54-cd6d0d9fa1cf',
#             tool_call_id='call_ZhQXuFuztghOzswFbdHnus03'
#         ),
#         AIMessage(
#             content='Your favourite colour is green.\n\nWould you like me to tailor anything
# around green—color palettes, themes for our chats, or recommendations in green shades? I can
# also share specific hex codes or shade variations if you’d like.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 502,
#                     'prompt_tokens': 287,
#                     'total_tokens': 789,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 448,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyPVLqCX2ikR4lreqXSKy6FW0kKeP',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc3a2-4e28-7442-acc2-d04642dffc8b-0',
#             usage_metadata={
#                 'input_tokens': 287,
#                 'output_tokens': 502,
#                 'total_tokens': 789,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 448}
#             }
#         )
#     ],
#     'favourite_colour': 'green'
# }
