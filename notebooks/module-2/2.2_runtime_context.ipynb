# %%
from dotenv import load_dotenv

load_dotenv()

from rich.console import Console
console = Console(width=96)

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

console.print(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='What is my favourite colour?',
#             additional_kwargs={},
#             response_metadata={},
#             id='83239a43-8fc0-4b2a-9ff0-ca7bb84192a4'
#         ),
#         AIMessage(
#             content='I don’t know your personal preferences unless you tell me. If you’d like,
# we can guess or figure it out together.\n\n- Quick guess: blue. Want me to guess again?\n- Or
# tell me a few colors you like and I’ll pick one.\n- Or I can suggest a color for a specific
# thing (outfit, room, design, etc.).',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 851,
#                     'prompt_tokens': 12,
#                     'total_tokens': 863,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 768,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyO7JApqD3wdgcSqvJHXpDWB5EPEZ',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc350-f2c5-7753-a288-146186771315-0',
#             usage_metadata={
#                 'input_tokens': 12,
#                 'output_tokens': 851,
#                 'total_tokens': 863,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 768}
#             }
#         )
#     ]
# }

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)
# Out:
# /Volumes/DataDrive/repo/nranthony/lca-lc-foundations/.venv/lib/python3.12/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='98f1ff26-f7f4-48ad-99f5-404de8a658c8'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 149, 'prompt_tokens': 149, 'total_tokens': 298, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CyO8uKaGnqbSBegaXvJ4RyXp1ZM5q', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bc352-75c6-71f1-849f-11abe97319e2-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'call_ft6foDCNuvlgFgne9J955kMY', 'type': 'tool_call'}], usage_metadata={'input_tokens': 149, 'output_tokens': 149, 'total_tokens': 298, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='8455b60a-f00e-4e28-a0ec-da2ff60dbe03', tool_call_id='call_ft6foDCNuvlgFgne9J955kMY'),
#               AIMessage(content='Your favourite colour is blue.\n\nWould you like me to also fetch your least favourite colour?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 283, 'prompt_tokens': 178, 'total_tokens': 461, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CyO8xFw9wTqlWHlyjaTITCyOOe7Nj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc352-81f5-76f0-8a1e-907fb9561424-0', usage_metadata={'input_tokens': 178, 'output_tokens': 283, 'total_tokens': 461, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}

# %%
console.print(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='What is my favourite colour?',
#             additional_kwargs={},
#             response_metadata={},
#             id='98f1ff26-f7f4-48ad-99f5-404de8a658c8'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 149,
#                     'prompt_tokens': 149,
#                     'total_tokens': 298,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 128,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyO8uKaGnqbSBegaXvJ4RyXp1ZM5q',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--019bc352-75c6-71f1-849f-11abe97319e2-0',
#             tool_calls=[
#                 {
#                     'name': 'get_favourite_colour',
#                     'args': {},
#                     'id': 'call_ft6foDCNuvlgFgne9J955kMY',
#                     'type': 'tool_call'
#                 }
#             ],
#             usage_metadata={
#                 'input_tokens': 149,
#                 'output_tokens': 149,
#                 'total_tokens': 298,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 128}
#             }
#         ),
#         ToolMessage(
#             content='blue',
#             name='get_favourite_colour',
#             id='8455b60a-f00e-4e28-a0ec-da2ff60dbe03',
#             tool_call_id='call_ft6foDCNuvlgFgne9J955kMY'
#         ),
#         AIMessage(
#             content='Your favourite colour is blue.\n\nWould you like me to also fetch your
# least favourite colour?',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 283,
#                     'prompt_tokens': 178,
#                     'total_tokens': 461,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 256,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyO8xFw9wTqlWHlyjaTITCyOOe7Nj',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc352-81f5-76f0-8a1e-907fb9561424-0',
#             usage_metadata={
#                 'input_tokens': 178,
#                 'output_tokens': 283,
#                 'total_tokens': 461,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 256}
#             }
#         )
#     ]
# }

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

console.print(response)
# Out:
# /Volumes/DataDrive/repo/nranthony/lca-lc-foundations/.venv/lib/python3.12/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {
#     'messages': [
#         HumanMessage(
#             content='What is my favourite colour?',
#             additional_kwargs={},
#             response_metadata={},
#             id='a68f0bce-fec1-4edb-b583-b0402aeb429d'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 213,
#                     'prompt_tokens': 149,
#                     'total_tokens': 362,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 192,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyP899z1iJboRWP0IRgM66ht4TDpy',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--019bc38c-636b-7c32-a1aa-9fd3873b988d-0',
#             tool_calls=[
#                 {
#                     'name': 'get_favourite_colour',
#                     'args': {},
#                     'id': 'call_fZHvHzHVkwJ4N3OzEX9n77IK',
#                     'type': 'tool_call'
#                 }
#             ],
#             usage_metadata={
#                 'input_tokens': 149,
#                 'output_tokens': 213,
#                 'total_tokens': 362,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 192}
#             }
#         ),
#         ToolMessage(
#             content='green',
#             name='get_favourite_colour',
#             id='8eccd797-b0a3-4aec-90cf-3b93772995b6',
#             tool_call_id='call_fZHvHzHVkwJ4N3OzEX9n77IK'
#         ),
#         AIMessage(
#             content='Your favourite colour is green.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 207,
#                     'prompt_tokens': 178,
#                     'total_tokens': 385,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 192,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyP8C6XQ3myolNg9cTQ57HvvR30gK',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc38c-6fe4-7533-b258-dac1bd981e62-0',
#             usage_metadata={
#                 'input_tokens': 178,
#                 'output_tokens': 207,
#                 'total_tokens': 385,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 192}
#             }
#         )
#     ]
# }
