# %%
from dotenv import load_dotenv

load_dotenv()

from rich.console import Console
console = Console(width=96)

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
console.print(tools)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='0d4ab6ae-f4e2-4ade-bac9-02d82e1f6ebb'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 588, 'prompt_tokens': 1229, 'total_tokens': 1817, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CyNx9481payawqewftvXXXHlHfAPV', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bc347-5311-76f3-9973-afdd56dcca92-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'passengers': {'adults': 1, 'children': 0, 'infants': 0}, 'cabinClass': 'M', 'sort': 'price', 'curr': 'EUR', 'locale': 'en'}, 'id': 'call_hgjGC2wAAYzAyH0GcnPC6Olh', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1229, 'output_tokens': 588, 'total_tokens': 1817, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T13:00:00.000Z",\n      "local": "2026-03-31T06:00:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T05:25:00.000Z",\n      "local": "2026-04-02T14:25:00.000"\n    },\n    "totalDurationInSeconds": 145500,\n    "durationInSeconds": 145500,\n    "price": 369,\n    "deepLink": "https://on.kiwi.com/y1gSyc",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "DEN",\n        "city": "Denver",\n        "cityCode": "DEN",\n        "arrival": {\n          "utc": "2026-03-31T15:47:00.000Z",\n          "local": "2026-03-31T09:47:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T00:25:00.000Z",\n          "local": "2026-03-31T18:25:00.000"\n        }\n      },\n      {\n        "at": "IAH",\n        "city": "Houston",\n        "cityCode": "HOU",\n        "arrival": {\n          "utc": "2026-04-01T03:01:00.000Z",\n          "local": "2026-03-31T22:01:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T15:25:00.000Z",\n          "local": "2026-04-01T10:25:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T23:45:00.000Z",\n      "local": "2026-03-31T16:45:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T11:00:00.000Z",\n      "local": "2026-04-01T20:00:00.000"\n    },\n    "totalDurationInSeconds": 40500,\n    "durationInSeconds": 40500,\n    "price": 409,\n    "deepLink": "https://on.kiwi.com/H21v5m",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T16:59:00.000Z",\n      "local": "2026-03-31T09:59:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T07:00:00.000Z",\n      "local": "2026-04-01T16:00:00.000"\n    },\n    "totalDurationInSeconds": 50460,\n    "durationInSeconds": 50460,\n    "price": 412,\n    "deepLink": "https://on.kiwi.com/OYni6I",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "SEA",\n        "city": "Seattle",\n        "cityCode": "SEA",\n        "arrival": {\n          "utc": "2026-03-31T19:16:00.000Z",\n          "local": "2026-03-31T12:16:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T20:50:00.000Z",\n          "local": "2026-03-31T13:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T16:59:00.000Z",\n      "local": "2026-03-31T09:59:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T07:00:00.000Z",\n      "local": "2026-04-01T16:00:00.000"\n    },\n    "totalDurationInSeconds": 50460,\n    "durationInSeconds": 50460,\n    "price": 417,\n    "deepLink": "https://on.kiwi.com/7FHu3j",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "SEA",\n        "city": "Seattle",\n        "cityCode": "SEA",\n        "arrival": {\n          "utc": "2026-03-31T19:16:00.000Z",\n          "local": "2026-03-31T12:16:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T20:50:00.000Z",\n          "local": "2026-03-31T13:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-04-01T06:30:00.000Z",\n      "local": "2026-03-31T23:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T14:30:00.000Z",\n      "local": "2026-04-02T23:30:00.000"\n    },\n    "totalDurationInSeconds": 115200,\n    "durationInSeconds": 115200,\n    "price": 422,\n    "deepLink": "https://on.kiwi.com/o51g2n",\n    "curr ...
#               AIMessage(content='Here are direct SFO → Tokyo (NRT) options for March 31, 2026.\n\nCheapest option\n| From → To | Departure & Arrival (local) | Cabin | Return Airports | Return times | Return cabin | Price | Deep link |\n|---|---|---|---|---|---|---|---|\n| SFO → NRT | 31/03 16:45 → 01/04 20:00 (11h 15m) | Economy | — | — | — | EUR 409 | https://on.kiwi.com/H21v5m |\n\nShortest duration options\n| From → To | Departure & Arrival (local) | Cabin | Return Airports | Return times | Return cabin | Price | Deep link |\n|---|---|---|---|---|---|---|---|\n| SFO → NRT | 31/03 12:20 → 01/04 15:25 (11h 05m) | Economy | — | — | — | EUR 1083 | https://on.kiwi.com/qHHFeJ |\n| SFO → NRT | 31/03 12:20 → 01/04 15:25 (11h 05m) | Economy | — | — | — | EUR 1090 | https://on.kiwi.com/qlXq3l |\n\nOther direct options\n- No other direct SFO → NRT options on March 31, 2026.\n\nHave a great trip! Fun fact: Tokyo has more Michelin-starred restaurants than any other city in the world.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6683, 'prompt_tokens': 5855, 'total_tokens': 12538, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 6336, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CyNxIroAIS7mL5BLlDraNwBk0tQzC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc347-79c5-7aa0-bf9b-7b31d7c729db-0', usage_metadata={'input_tokens': 5855, 'output_tokens': 6683, 'total_tokens': 12538, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 6336}})]}

# %%
console.print(response)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='Get me a direct flight from San Francisco to Tokyo on March 31st',
#             additional_kwargs={},
#             response_metadata={},
#             id='0d4ab6ae-f4e2-4ade-bac9-02d82e1f6ebb'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 588,
#                     'prompt_tokens': 1229,
#                     'total_tokens': 1817,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 512,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyNx9481payawqewftvXXXHlHfAPV',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--019bc347-5311-76f3-9973-afdd56dcca92-0',
#             tool_calls=[
#                 {
#                     'name': 'search-flight',
#                     'args': {
#                         'flyFrom': 'San Francisco',
#                         'flyTo': 'Tokyo',
#                         'departureDate': '31/03/2026',
#                         'passengers': {'adults': 1, 'children': 0, 'infants': 0},
#                         'cabinClass': 'M',
#                         'sort': 'price',
#                         'curr': 'EUR',
#                         'locale': 'en'
#                     },
#                     'id': 'call_hgjGC2wAAYzAyH0GcnPC6Olh',
#                     'type': 'tool_call'
#                 }
#             ],
#             usage_metadata={
#                 'input_tokens': 1229,
#                 'output_tokens': 588,
#                 'total_tokens': 1817,
#                 'input_token_details': {'audio': 0, 'cache_read': 1024},
#                 'output_token_details': {'audio': 0, 'reasoning': 512}
#             }
#         ),
#         ToolMessage(
#             content=[
#                 {
#                     'type': 'text',
#                     'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom":
# "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc":
# "2026-03-31T13:00:00.000Z",\n      "local": "2026-03-31T06:00:00.000"\n    },\n    "arrival":
# {\n      "utc": "2026-04-02T05:25:00.000Z",\n      "local": "2026-04-02T14:25:00.000"\n    },\n
# "totalDurationInSeconds": 145500,\n    "durationInSeconds": 145500,\n    "price": 369,\n
# "deepLink": "https://on.kiwi.com/y1gSyc",\n    "currency": "EUR",\n    "layovers": [\n      {\n
# "at": "DEN",\n        "city": "Denver",\n        "cityCode": "DEN",\n        "arrival": {\n
# "utc": "2026-03-31T15:47:00.000Z",\n          "local": "2026-03-31T09:47:00.000"\n        },\n
# "departure": {\n          "utc": "2026-04-01T00:25:00.000Z",\n          "local":
# "2026-03-31T18:25:00.000"\n        }\n      },\n      {\n        "at": "IAH",\n        "city":
# "Houston",\n        "cityCode": "HOU",\n        "arrival": {\n          "utc":
# "2026-04-01T03:01:00.000Z",\n          "local": "2026-03-31T22:01:00.000"\n        },\n
# "departure": {\n          "utc": "2026-04-01T15:25:00.000Z",\n          "local":
# "2026-04-01T10:25:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n
# "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n
# "utc": "2026-03-31T23:45:00.000Z",\n      "local": "2026-03-31T16:45:00.000"\n    },\n
# "arrival": {\n      "utc": "2026-04-01T11:00:00.000Z",\n      "local":
# "2026-04-01T20:00:00.000"\n    },\n    "totalDurationInSeconds": 40500,\n
# "durationInSeconds": 40500,\n    "price": 409,\n    "deepLink": "https://on.kiwi.com/H21v5m",\n
# "currency": "EUR"\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San
# Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc":
# "2026-03-31T16:59:00.000Z",\n      "local": "2026-03-31T09:59:00.000"\n    },\n    "arrival":
# {\n      "utc": "2026-04-01T07:00:00.000Z",\n      "local": "2026-04-01T16:00:00.000"\n    },\n
# "totalDurationInSeconds": 50460,\n    "durationInSeconds": 50460,\n    "price": 412,\n
# "deepLink": "https://on.kiwi.com/OYni6I",\n    "currency": "EUR",\n    "layovers": [\n      {\n
# "at": "SEA",\n        "city": "Seattle",\n        "cityCode": "SEA",\n        "arrival": {\n
# "utc": "2026-03-31T19:16:00.000Z",\n          "local": "2026-03-31T12:16:00.000"\n        },\n
# "departure": {\n          "utc": "2026-03-31T20:50:00.000Z",\n          "local":
# "2026-03-31T13:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n
# "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n
# "utc": "2026-03-31T16:59:00.000Z",\n      "local": "2026-03-31T09:59:00.000"\n    },\n
# "arrival": {\n      "utc": "2026-04-01T07:00:00.000Z",\n      "local":
# "2026-04-01T16:00:00.000"\n    },\n    "totalDurationInSeconds": 50460,\n
# "durationInSeconds": 50460,\n    "price": 417,\n    "deepLink": "https://on.kiwi.com/7FHu3j",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "SEA",\n        "city":
# "Seattle",\n        "cityCode": "SEA",\n        "arrival": {\n          "utc":
# "2026-03-31T19:16:00.000Z",\n          "local": "2026-03-31T12:16:00.000"\n        },\n
# "departure": {\n          "utc": "2026-03-31T20:50:00.000Z",\n          "local":
# "2026-03-31T13:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n
# "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n
# "utc": "2026-04-01T06:30:00.000Z",\n      "local": "2026-03-31T23:30:00.000"\n    },\n
# "arrival": {\n      "utc": "2026-04-02T14:30:00.000Z",\n      "local":
# "2026-04-02T23:30:00.000"\n    },\n    "totalDurationInSeconds": 115200,\n
# "durationInSeconds": 115200,\n    "price": 422,\n    "deepLink": "https://on.kiwi.com/o51g2n",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "ICN",\n        "city": "Seoul",\n
# "cityCode": "SEL",\n        "arrival": {\n          "utc": "2026-04-01T19:30:00.000Z",\n
# "local": "2026-04-02T04:30:00.000"\n        },\n        "departure": {\n          "utc":
# "2026-04-02T12:10:00.000Z",\n          "local": "2026-04-02T21:10:00.000"\n        }\n      }\n
# ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n
# "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local":
# "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:40:00.000Z",\n
# "local": "2026-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 96600,\n
# "durationInSeconds": 96600,\n    "price": 446,\n    "deepLink": "https://on.kiwi.com/g1AbgW",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city":
# "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc":
# "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n
# "departure": {\n          "utc": "2026-04-01T07:20:00.000Z",\n          "local":
# "2026-04-01T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n
# "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n
# "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T00:25:00.000"\n    },\n
# "arrival": {\n      "utc": "2026-04-01T10:40:00.000Z",\n      "local":
# "2026-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 98100,\n
# "durationInSeconds": 98100,\n    "price": 446,\n    "deepLink": "https://on.kiwi.com/2DtkdP",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city":
# "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc":
# "2026-03-31T21:15:00.000Z",\n          "local": "2026-04-01T05:15:00.000"\n        },\n
# "departure": {\n          "utc": "2026-04-01T07:20:00.000Z",\n          "local":
# "2026-04-01T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n
# "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n
# "utc": "2026-04-01T06:30:00.000Z",\n      "local": "2026-03-31T23:30:00.000"\n    },\n
# "arrival": {\n      "utc": "2026-04-02T09:25:00.000Z",\n      "local":
# "2026-04-02T18:25:00.000"\n    },\n    "totalDurationInSeconds": 96900,\n
# "durationInSeconds": 96900,\n    "price": 451,\n    "deepLink": "https://on.kiwi.com/WgpLJN",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "ICN",\n        "city": "Seoul",\n
# "cityCode": "SEL",\n        "arrival": {\n          "utc": "2026-04-01T19:30:00.000Z",\n
# "local": "2026-04-02T04:30:00.000"\n        },\n        "departure": {\n          "utc":
# "2026-04-02T06:45:00.000Z",\n          "local": "2026-04-02T15:45:00.000"\n        }\n      }\n
# ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n
# "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-04-01T06:30:00.000Z",\n      "local":
# "2026-03-31T23:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T12:00:00.000Z",\n
# "local": "2026-04-02T21:00:00.000"\n    },\n    "totalDurationInSeconds": 106200,\n
# "durationInSeconds": 106200,\n    "price": 451,\n    "deepLink": "https://on.kiwi.com/areG0k",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "ICN",\n        "city": "Seoul",\n
# "cityCode": "SEL",\n        "arrival": {\n          "utc": "2026-04-01T19:30:00.000Z",\n
# "local": "2026-04-02T04:30:00.000"\n        },\n        "departure": {\n          "utc":
# "2026-04-02T09:30:00.000Z",\n          "local": "2026-04-02T18:30:00.000"\n        }\n      }\n
# ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n
# "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-04-01T03:09:00.000Z",\n      "local":
# "2026-03-31T20:09:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T05:10:00.000Z",\n
# "local": "2026-04-02T14:10:00.000"\n    },\n    "totalDurationInSeconds": 93660,\n
# "durationInSeconds": 93660,\n    "price": 481,\n    "deepLink": "https://on.kiwi.com/cwNjpH",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "LAX",\n        "city": "Los
# Angeles",\n        "cityCode": "LAX",\n        "arrival": {\n          "utc":
# "2026-04-01T04:39:00.000Z",\n          "local": "2026-03-31T21:39:00.000"\n        },\n
# "departure": {\n          "utc": "2026-04-01T17:25:00.000Z",\n          "local":
# "2026-04-01T10:25:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n
# "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n
# "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n
# "arrival": {\n      "utc": "2026-04-01T03:55:00.000Z",\n      "local":
# "2026-04-01T12:55:00.000"\n    },\n    "totalDurationInSeconds": 72300,\n
# "durationInSeconds": 72300,\n    "price": 500,\n    "deepLink": "https://on.kiwi.com/pruQIb",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city":
# "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc":
# "2026-03-31T21:25:00.000Z",\n          "local": "2026-04-01T05:25:00.000"\n        },\n
# "departure": {\n          "utc": "2026-04-01T00:30:00.000Z",\n          "local":
# "2026-04-01T08:30:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n
# "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n
# "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n
# "arrival": {\n      "utc": "2026-04-01T06:05:00.000Z",\n      "local":
# "2026-04-01T15:05:00.000"\n    },\n    "totalDurationInSeconds": 80100,\n
# "durationInSeconds": 80100,\n    "price": 500,\n    "deepLink": "https://on.kiwi.com/Ak3bWp",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city":
# "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc":
# "2026-03-31T21:25:00.000Z",\n          "local": "2026-04-01T05:25:00.000"\n        },\n
# "departure": {\n          "utc": "2026-04-01T02:40:00.000Z",\n          "local":
# "2026-04-01T10:40:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n
# "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n
# "utc": "2026-04-01T06:30:00.000Z",\n      "local": "2026-03-31T23:30:00.000"\n    },\n
# "arrival": {\n      "utc": "2026-04-02T02:20:00.000Z",\n      "local":
# "2026-04-02T11:20:00.000"\n    },\n    "totalDurationInSeconds": 71400,\n
# "durationInSeconds": 71400,\n    "price": 524,\n    "deepLink": "https://on.kiwi.com/TFDL8H",\n
# "currency": "EUR",\n    "layovers": [\n      {\n        "at": "ICN",\n        "city": "Seoul",\n
# "cityCode": "SEL",\n        "arrival": {\n          "utc": "2026-04-01T19:30:00.000Z",\n
# "local": "2026-04-02T04:30:00.000"\n        },\n        "departure": {\n          "utc":
# "2026-04-02T00:00:00.000Z",\n          "local": "2026-04-02T09:00:00.000"\n        }\n      }\n
# ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n
# "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T19:20:00.000Z",\n      "local":
# "2026-03-31T12:20:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T06:25:00.000Z",\n
# "local": "2026-04-01T15:25:00.000"\n    },\n    "totalDurationInSeconds": 39900,\n
# "durationInSeconds": 39900,\n    "price": 1083,\n    "deepLink": "https://on.kiwi.com/qHHFeJ",\n
# "currency": "EUR"\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San
# Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc":
# "2026-03-31T19:20:00.000Z",\n      "local": "2026-03-31T12:20:00.000"\n    },\n    "arrival":
# {\n      "utc": "2026-04-01T06:25:00.000Z",\n      "local": "2026-04-01T15:25:00.000"\n    },\n
# "totalDurationInSeconds": 39900,\n    "durationInSeconds": 39900,\n    "price": 1090,\n
# "deepLink": "https://on.kiwi.com/qlXq3l",\n    "currency": "EUR"\n  }\n]',
#                     'id': 'lc_213fa954-a6d4-4c95-9815-b9e06eb03e39'
#                 }
#             ],
#             name='search-flight',
#             id='3c726dcd-1872-48a7-9a6d-3419798f0223',
#             tool_call_id='call_hgjGC2wAAYzAyH0GcnPC6Olh'
#         ),
#         AIMessage(
#             content='Here are direct SFO → Tokyo (NRT) options for March 31, 2026.\n\nCheapest
# option\n| From → To | Departure & Arrival (local) | Cabin | Return Airports | Return times |
# Return cabin | Price | Deep link |\n|---|---|---|---|---|---|---|---|\n| SFO → NRT | 31/03 16:45
# → 01/04 20:00 (11h 15m) | Economy | — | — | — | EUR 409 | https://on.kiwi.com/H21v5m
# |\n\nShortest duration options\n| From → To | Departure & Arrival (local) | Cabin | Return
# Airports | Return times | Return cabin | Price | Deep link
# |\n|---|---|---|---|---|---|---|---|\n| SFO → NRT | 31/03 12:20 → 01/04 15:25 (11h 05m) |
# Economy | — | — | — | EUR 1083 | https://on.kiwi.com/qHHFeJ |\n| SFO → NRT | 31/03 12:20 → 01/04
# 15:25 (11h 05m) | Economy | — | — | — | EUR 1090 | https://on.kiwi.com/qlXq3l |\n\nOther direct
# options\n- No other direct SFO → NRT options on March 31, 2026.\n\nHave a great trip! Fun fact:
# Tokyo has more Michelin-starred restaurants than any other city in the world.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 6683,
#                     'prompt_tokens': 5855,
#                     'total_tokens': 12538,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 6336,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-nano-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-CyNxIroAIS7mL5BLlDraNwBk0tQzC',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--019bc347-79c5-7aa0-bf9b-7b31d7c729db-0',
#             usage_metadata={
#                 'input_tokens': 5855,
#                 'output_tokens': 6683,
#                 'total_tokens': 12538,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 6336}
#             }
#         )
#     ]
# }

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct SFO → Tokyo (NRT) options for March 31, 2026.
#
# Cheapest option
# | From → To | Departure & Arrival (local) | Cabin | Return Airports | Return times | Return cabin | Price | Deep link |
# |---|---|---|---|---|---|---|---|
# | SFO → NRT | 31/03 16:45 → 01/04 20:00 (11h 15m) | Economy | — | — | — | EUR 409 | https://on.kiwi.com/H21v5m |
#
# Shortest duration options
# | From → To | Departure & Arrival (local) | Cabin | Return Airports | Return times | Return cabin | Price | Deep link |
# |---|---|---|---|---|---|---|---|
# | SFO → NRT | 31/03 12:20 → 01/04 15:25 (11h 05m) | Economy | — | — | — | EUR 1083 | https://on.kiwi.com/qHHFeJ |
# | SFO → NRT | 31/03 12:20 → 01/04 15:25 (11h 05m) | Economy | — | — | — | EUR 1090 | https://on.kiwi.com/qlXq3l |
#
# Other direct options
# - No other direct SFO → NRT options on March 31, 2026.
#
# Have a great trip! Fun fact: Tokyo has more Michelin-starred restaurants than any other city in the world.

# %%
console.print(list(response['messages'])[2].content[0]['text'])
# Out:
# [
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T13:00:00.000Z",
#       "local": "2026-03-31T06:00:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-02T05:25:00.000Z",
#       "local": "2026-04-02T14:25:00.000"
#     },
#     "totalDurationInSeconds": 145500,
#     "durationInSeconds": 145500,
#     "price": 369,
#     "deepLink": "https://on.kiwi.com/y1gSyc",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "DEN",
#         "city": "Denver",
#         "cityCode": "DEN",
#         "arrival": {
#           "utc": "2026-03-31T15:47:00.000Z",
#           "local": "2026-03-31T09:47:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-01T00:25:00.000Z",
#           "local": "2026-03-31T18:25:00.000"
#         }
#       },
#       {
#         "at": "IAH",
#         "city": "Houston",
#         "cityCode": "HOU",
#         "arrival": {
#           "utc": "2026-04-01T03:01:00.000Z",
#           "local": "2026-03-31T22:01:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-01T15:25:00.000Z",
#           "local": "2026-04-01T10:25:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T23:45:00.000Z",
#       "local": "2026-03-31T16:45:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-01T11:00:00.000Z",
#       "local": "2026-04-01T20:00:00.000"
#     },
#     "totalDurationInSeconds": 40500,
#     "durationInSeconds": 40500,
#     "price": 409,
#     "deepLink": "https://on.kiwi.com/H21v5m",
#     "currency": "EUR"
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T16:59:00.000Z",
#       "local": "2026-03-31T09:59:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-01T07:00:00.000Z",
#       "local": "2026-04-01T16:00:00.000"
#     },
#     "totalDurationInSeconds": 50460,
#     "durationInSeconds": 50460,
#     "price": 412,
#     "deepLink": "https://on.kiwi.com/OYni6I",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "SEA",
#         "city": "Seattle",
#         "cityCode": "SEA",
#         "arrival": {
#           "utc": "2026-03-31T19:16:00.000Z",
#           "local": "2026-03-31T12:16:00.000"
#         },
#         "departure": {
#           "utc": "2026-03-31T20:50:00.000Z",
#           "local": "2026-03-31T13:50:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T16:59:00.000Z",
#       "local": "2026-03-31T09:59:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-01T07:00:00.000Z",
#       "local": "2026-04-01T16:00:00.000"
#     },
#     "totalDurationInSeconds": 50460,
#     "durationInSeconds": 50460,
#     "price": 417,
#     "deepLink": "https://on.kiwi.com/7FHu3j",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "SEA",
#         "city": "Seattle",
#         "cityCode": "SEA",
#         "arrival": {
#           "utc": "2026-03-31T19:16:00.000Z",
#           "local": "2026-03-31T12:16:00.000"
#         },
#         "departure": {
#           "utc": "2026-03-31T20:50:00.000Z",
#           "local": "2026-03-31T13:50:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "HND",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-04-01T06:30:00.000Z",
#       "local": "2026-03-31T23:30:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-02T14:30:00.000Z",
#       "local": "2026-04-02T23:30:00.000"
#     },
#     "totalDurationInSeconds": 115200,
#     "durationInSeconds": 115200,
#     "price": 422,
#     "deepLink": "https://on.kiwi.com/o51g2n",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "ICN",
#         "city": "Seoul",
#         "cityCode": "SEL",
#         "arrival": {
#           "utc": "2026-04-01T19:30:00.000Z",
#           "local": "2026-04-02T04:30:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-02T12:10:00.000Z",
#           "local": "2026-04-02T21:10:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T07:50:00.000Z",
#       "local": "2026-03-31T00:50:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-01T10:40:00.000Z",
#       "local": "2026-04-01T19:40:00.000"
#     },
#     "totalDurationInSeconds": 96600,
#     "durationInSeconds": 96600,
#     "price": 446,
#     "deepLink": "https://on.kiwi.com/g1AbgW",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "TPE",
#         "city": "Taipei",
#         "cityCode": "TPE",
#         "arrival": {
#           "utc": "2026-03-31T21:40:00.000Z",
#           "local": "2026-04-01T05:40:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-01T07:20:00.000Z",
#           "local": "2026-04-01T15:20:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T07:25:00.000Z",
#       "local": "2026-03-31T00:25:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-01T10:40:00.000Z",
#       "local": "2026-04-01T19:40:00.000"
#     },
#     "totalDurationInSeconds": 98100,
#     "durationInSeconds": 98100,
#     "price": 446,
#     "deepLink": "https://on.kiwi.com/2DtkdP",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "TPE",
#         "city": "Taipei",
#         "cityCode": "TPE",
#         "arrival": {
#           "utc": "2026-03-31T21:15:00.000Z",
#           "local": "2026-04-01T05:15:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-01T07:20:00.000Z",
#           "local": "2026-04-01T15:20:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-04-01T06:30:00.000Z",
#       "local": "2026-03-31T23:30:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-02T09:25:00.000Z",
#       "local": "2026-04-02T18:25:00.000"
#     },
#     "totalDurationInSeconds": 96900,
#     "durationInSeconds": 96900,
#     "price": 451,
#     "deepLink": "https://on.kiwi.com/WgpLJN",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "ICN",
#         "city": "Seoul",
#         "cityCode": "SEL",
#         "arrival": {
#           "utc": "2026-04-01T19:30:00.000Z",
#           "local": "2026-04-02T04:30:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-02T06:45:00.000Z",
#           "local": "2026-04-02T15:45:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-04-01T06:30:00.000Z",
#       "local": "2026-03-31T23:30:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-02T12:00:00.000Z",
#       "local": "2026-04-02T21:00:00.000"
#     },
#     "totalDurationInSeconds": 106200,
#     "durationInSeconds": 106200,
#     "price": 451,
#     "deepLink": "https://on.kiwi.com/areG0k",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "ICN",
#         "city": "Seoul",
#         "cityCode": "SEL",
#         "arrival": {
#           "utc": "2026-04-01T19:30:00.000Z",
#           "local": "2026-04-02T04:30:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-02T09:30:00.000Z",
#           "local": "2026-04-02T18:30:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-04-01T03:09:00.000Z",
#       "local": "2026-03-31T20:09:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-02T05:10:00.000Z",
#       "local": "2026-04-02T14:10:00.000"
#     },
#     "totalDurationInSeconds": 93660,
#     "durationInSeconds": 93660,
#     "price": 481,
#     "deepLink": "https://on.kiwi.com/cwNjpH",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "LAX",
#         "city": "Los Angeles",
#         "cityCode": "LAX",
#         "arrival": {
#           "utc": "2026-04-01T04:39:00.000Z",
#           "local": "2026-03-31T21:39:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-01T17:25:00.000Z",
#           "local": "2026-04-01T10:25:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T07:50:00.000Z",
#       "local": "2026-03-31T00:50:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-01T03:55:00.000Z",
#       "local": "2026-04-01T12:55:00.000"
#     },
#     "totalDurationInSeconds": 72300,
#     "durationInSeconds": 72300,
#     "price": 500,
#     "deepLink": "https://on.kiwi.com/pruQIb",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "TPE",
#         "city": "Taipei",
#         "cityCode": "TPE",
#         "arrival": {
#           "utc": "2026-03-31T21:25:00.000Z",
#           "local": "2026-04-01T05:25:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-01T00:30:00.000Z",
#           "local": "2026-04-01T08:30:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T07:50:00.000Z",
#       "local": "2026-03-31T00:50:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-01T06:05:00.000Z",
#       "local": "2026-04-01T15:05:00.000"
#     },
#     "totalDurationInSeconds": 80100,
#     "durationInSeconds": 80100,
#     "price": 500,
#     "deepLink": "https://on.kiwi.com/Ak3bWp",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "TPE",
#         "city": "Taipei",
#         "cityCode": "TPE",
#         "arrival": {
#           "utc": "2026-03-31T21:25:00.000Z",
#           "local": "2026-04-01T05:25:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-01T02:40:00.000Z",
#           "local": "2026-04-01T10:40:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-04-01T06:30:00.000Z",
#       "local": "2026-03-31T23:30:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-02T02:20:00.000Z",
#       "local": "2026-04-02T11:20:00.000"
#     },
#     "totalDurationInSeconds": 71400,
#     "durationInSeconds": 71400,
#     "price": 524,
#     "deepLink": "https://on.kiwi.com/TFDL8H",
#     "currency": "EUR",
#     "layovers": [
#       {
#         "at": "ICN",
#         "city": "Seoul",
#         "cityCode": "SEL",
#         "arrival": {
#           "utc": "2026-04-01T19:30:00.000Z",
#           "local": "2026-04-02T04:30:00.000"
#         },
#         "departure": {
#           "utc": "2026-04-02T00:00:00.000Z",
#           "local": "2026-04-02T09:00:00.000"
#         }
#       }
#     ]
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T19:20:00.000Z",
#       "local": "2026-03-31T12:20:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-01T06:25:00.000Z",
#       "local": "2026-04-01T15:25:00.000"
#     },
#     "totalDurationInSeconds": 39900,
#     "durationInSeconds": 39900,
#     "price": 1083,
#     "deepLink": "https://on.kiwi.com/qHHFeJ",
#     "currency": "EUR"
#   },
#   {
#     "flyFrom": "SFO",
#     "flyTo": "NRT",
#     "cityFrom": "San Francisco",
#     "cityTo": "Tokyo",
#     "departure": {
#       "utc": "2026-03-31T19:20:00.000Z",
#       "local": "2026-03-31T12:20:00.000"
#     },
#     "arrival": {
#       "utc": "2026-04-01T06:25:00.000Z",
#       "local": "2026-04-01T15:25:00.000"
#     },
#     "totalDurationInSeconds": 39900,
#     "durationInSeconds": 39900,
#     "price": 1090,
#     "deepLink": "https://on.kiwi.com/qlXq3l",
#     "currency": "EUR"
#   }
# ]

# %%
list(response['messages'])[2].content[0]
# Out:
# {'type': 'text',
#  'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T13:00:00.000Z",\n      "local": "2026-03-31T06:00:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T05:25:00.000Z",\n      "local": "2026-04-02T14:25:00.000"\n    },\n    "totalDurationInSeconds": 145500,\n    "durationInSeconds": 145500,\n    "price": 369,\n    "deepLink": "https://on.kiwi.com/y1gSyc",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "DEN",\n        "city": "Denver",\n        "cityCode": "DEN",\n        "arrival": {\n          "utc": "2026-03-31T15:47:00.000Z",\n          "local": "2026-03-31T09:47:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T00:25:00.000Z",\n          "local": "2026-03-31T18:25:00.000"\n        }\n      },\n      {\n        "at": "IAH",\n        "city": "Houston",\n        "cityCode": "HOU",\n        "arrival": {\n          "utc": "2026-04-01T03:01:00.000Z",\n          "local": "2026-03-31T22:01:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T15:25:00.000Z",\n          "local": "2026-04-01T10:25:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T23:45:00.000Z",\n      "local": "2026-03-31T16:45:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T11:00:00.000Z",\n      "local": "2026-04-01T20:00:00.000"\n    },\n    "totalDurationInSeconds": 40500,\n    "durationInSeconds": 40500,\n    "price": 409,\n    "deepLink": "https://on.kiwi.com/H21v5m",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T16:59:00.000Z",\n      "local": "2026-03-31T09:59:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T07:00:00.000Z",\n      "local": "2026-04-01T16:00:00.000"\n    },\n    "totalDurationInSeconds": 50460,\n    "durationInSeconds": 50460,\n    "price": 412,\n    "deepLink": "https://on.kiwi.com/OYni6I",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "SEA",\n        "city": "Seattle",\n        "cityCode": "SEA",\n        "arrival": {\n          "utc": "2026-03-31T19:16:00.000Z",\n          "local": "2026-03-31T12:16:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T20:50:00.000Z",\n          "local": "2026-03-31T13:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T16:59:00.000Z",\n      "local": "2026-03-31T09:59:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T07:00:00.000Z",\n      "local": "2026-04-01T16:00:00.000"\n    },\n    "totalDurationInSeconds": 50460,\n    "durationInSeconds": 50460,\n    "price": 417,\n    "deepLink": "https://on.kiwi.com/7FHu3j",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "SEA",\n        "city": "Seattle",\n        "cityCode": "SEA",\n        "arrival": {\n          "utc": "2026-03-31T19:16:00.000Z",\n          "local": "2026-03-31T12:16:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T20:50:00.000Z",\n          "local": "2026-03-31T13:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-04-01T06:30:00.000Z",\n      "local": "2026-03-31T23:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T14:30:00.000Z",\n      "local": "2026-04-02T23:30:00.000"\n    },\n    "totalDurationInSeconds": 115200,\n    "durationInSeconds": 115200,\n    "price": 422,\n    "deepLink": "https://on.kiwi.com/o51g2n",\n    "currency": "EUR",\n    "layovers": [\n      {\n         ...
#  'id': 'lc_213fa954-a6d4-4c95-9815-b9e06eb03e39'}
